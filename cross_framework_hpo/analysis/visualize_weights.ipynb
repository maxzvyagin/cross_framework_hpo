# %%
from crossedwires.cifar10 import ResNet50Dataset, VGG16Dataset, DenseNet121Dataset

# %%
d = ResNet50Dataset()

# %%
df = d.wandb_dataframe()

# %%
df
# Out:
#                     Name  accuracy_diff  pt_test_acc  tf_test_acc     State  \
# 0    dual_train_85721cc8       0.452007     0.570107       0.1181  finished
# 1    dual_train_f7099482       0.435161     0.551261       0.1161  finished
# 2    dual_train_fcdc666a       0.430048     0.562548       0.1325  finished
# 3    dual_train_21b65dba       0.422199     0.522199       0.1000  finished
# 4    dual_train_807e7310       0.409086     0.559586       0.1505  finished
# ..                   ...            ...          ...          ...       ...
# 395  dual_train_5ac692ce       0.000800     0.098300       0.0991  finished
# 396  dual_train_f416de3a       0.000732     0.574932       0.5742  finished
# 397  dual_train_54dc1862       0.000569     0.436069       0.4355  finished
# 398  dual_train_5efd9218       0.000316     0.559484       0.5598  finished
# 399  dual_train_98577868       0.000137     0.605537       0.6054  finished
#
# ...

# %%
torch_model = d.get_pytorch_model('dual_train_85721cc8')

# %%
tensorflow_model = d.get_tensorflow_model('dual_train_fcdc666a')
# Out:
# Tensorflow Model definition has been saved to /tmp/resnet_lambda_dual_train_fcdc666atf_model/. Feel free to call get_tensorflow_model(trial_name).
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-10205ade2bf7> in <module>
# ----> 1 tensorflow_model = d.get_tensorflow_model('dual_train_fcdc666a')
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/crossedwires/cifar10/resnet50/resnet50_results.py in get_tensorflow_model(self, trial_name)
#      51         if not exists(weights_file_name):
#      52             self.get_tensorflow_weights(trial_name)
# ---> 53         model = tf.keras.models.load_model(weights_file_name)
#      54         return model
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
# ...

# %%
torch_model._modules['conv1']._parameters['weight'].shape
# Out:
# torch.Size([64, 3, 7, 7])
