# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Generation of Plots for VGG

# %%
vgg_df = pd.read_csv('../wandb_results/vgg_cifar10_wandb_export.csv')

# %%
pt_test_acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-327-165b0f7591d4> in <module>
# ----> 1 pt_test_acc
#
# NameError: name 'pt_test_acc' is not defined

# %%
len(['pt_test_acc']*400)
# Out:
# 400

# %%
list(vgg_df['accuracy_diff'])
# Out:
# [0.6815193943679333,
#  0.6561938039057857,
#  0.6532896370405242,
#  0.6471332620297161,
#  0.6318242860639968,
#  0.6274801574292637,
#  0.5769280906427989,
#  0.5159618644551798,
#  0.5099999874830246,
#  0.5019994948990643,
#  0.4591645408760418,
#  0.389905346930027,
#  0.3836100605480811,
#  0.3774291732731987,
#  0.35380327701568604,
#  0.3438066813078793,
#  0.3331725696722666,
#  0.3324991977214813,
#  0.33029610912005103,
#  0.3291061818599701,
#  0.3203251163164774,
#  0.32021256536245346,
#  0.3164526025454203,
#  0.3158659040927887,
#  0.3140484217335197,
#  0.3116181872107766,
#  0.3103571963660857,
#  0.30199628571669257,
#  0.2962668657302856,
#  0.2956711519509554,
#  0.293813924055274,
#  0.2919785678386688,
#  0.287836651167562,
#  0.28766218225161233,
#  0.2830999791622162,
#  0.2793999791145325,
#  0.27853493858128786,
#  0.27833640846339136,
#  0.2780174563328425,
#  0.276868020494779,
#  0.27536501667716284,
#  0.2735571811596552,
#  0.27265599099072546,
#  0.2712582449118296,
#  0.2705016692479452,
#  0.2704589366912842,
#  0.2698154151439667,
#  0.2678217940470752,
#  0.26543935388326645,
#  0.2649417449446285,
#  0.26237318158149714,
#  0.25967642664909363,
#  0.25918728426883103,
#  0.25884589643189404,
#  0.2558729276061058,
#  0.25510000884532924,
#  0.2527375045147809,
#  0.251581625026815,
#  0.2494524518648783,
#  0.2492038458585739,
#  0.24876159997213454,
#  0.24813394745190945,
#  0.2479060081874623,
#  0.24730664762583646,
#  0.24436112244923916,
#  0.2435258358716965,
#  0.2417087554931641,
#  0.24014171957969666,
#  0.2400129343108307,
#  0.23991375348784705,
#  0.2396737622178119,
#  0.23819999396800995,
#  0.2380390921059776,
#  0.2367445750207436,
#  0.23485236465930934,
#  0.23278256257375085,
#  0.2316114217042923,
#  0.2305491096095035,
#  0.23041832021304545,
#  0.2271901469941091,
#  0.2248892328318428,
#  0.22093355197172893,
#  0.21851197355671936,
#  0.21710744209405847,
#  0.2157836382587751,
#  0.21222418298323947,
#  0.2120799385011196,
#  0.2112017059150864,
#  0.21079588637632485,
#  0.20955442856339845,
#  0.2080276147885756,
#  0.20776692288262502,
#  0.20702599485715228,
#  0.2038796579136568,
#  0.20135610103607174,
#  0.19858444788876706,
#  0.19813737273216248,
#  0.19437186047434807,
#  0.1941089890897274,
#  0.1923597866726905,
#  0.1911844611167908,
#  0.009721093707614424,
#  0.00871197666440693,
#  0.008408325910568282,
#  0.008154564782192786,
#  0.008072611163644217,
#  0.007766106854314336,
#  0.007591552459276674,
#  0.007564021443778823,
#  0.00745670935686893,
#  0.007416192442178726,
#  0.006875105698903372,
#  0.006827473640441895,
#  0.006609634655277863,
#  0.0064052145292119314,
#  0.00638776340267877,
#  0.005684445951586571,
#  0.0054834052210762365,
#  0.004828604784878815,
#  0.0047725673232760215,
#  0.004497709065458211,
#  0.004087267559953035,
#  0.0037935361629579663,
#  0.003706465749179655,
#  0.0029653324080365084,
#  0.0029619336128234863,
#  0.002400004863739036,
#  0.0023681393691471486,
#  0.0020325346426530717,
#  0.001936072652990117,
#  0.001915313303470612,
#  0.0016734359992875009,
#  0.00145578842896682,
#  0.0014085715467279105,
#  0.001266534129778507,
#  0.001019500195980072,
#  0.0007329157420566945,
#  0.0006404252428757473,
#  0.0006061634596656318,
#  0.0004840389721923466,
#  0.00037999096370879015,
#  0.00036466392603787257,
#  0.00035689737309109465,
#  0.0003189777857378895,
#  0.0002482353399197307,
#  0.0002065277317675196,
#  7.974323734902256e-05,
#  7.455774089869249e-05,
#  7.455774089869249e-05,
#  5.480376156893896e-05,
#  5.364396116312731e-05,
#  4.4011821349457254e-05,
#  3.139148740206876e-05,
#  1.64741650223732e-05,
#  1.6123522073030472e-06,
#  2.6026765742592772e-09,
#  1.4901161138336505e-09,
#  1.4901161138336505e-09,
#  1.4901161138336505e-09,
#  4.172325124285337e-10,
#  4.172325124285337e-10,
#  4.172325124285337e-10,
#  4.172325124285337e-10,
#  4.172325124285337e-10,
#  4.172325124285337e-10,
#  nan,
#  nan]

# %%
all_stats = list(vgg_df['pt_test_acc'])
all_stats.extend(list(vgg_df['tf_test_acc']))
all_stats.extend(list(vgg_df['accuracy_diff']))

all_names = (['PT Test Accuracy']*400)
all_names.extend(['TF Test Accuracy']*400)
all_names.extend(['Accuracy Diff']*400)

# %%
vgg_stats_df = pd.DataFrame({'Value': all_stats, 'Statistic': all_names})

# %%
plt.rcdefaults()

# %%
import matplotlib.pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 18
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE, figsize=(1, 1))  # fontsize of the figure title

# %%
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %%
viridis = sns.color_palette("viridis")
viridis_colors = [viridis[0], viridis[2], viridis[5]]

# %%
# sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
ax = sns.displot(vgg_stats_df, x="Value", hue="Statistic", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, legend=False, aspect=1.5)
# plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
# plt.setp(ax._legend.get_title(), fontsize='16')
# ax._legend._loc_real = 1
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
plt.tight_layout()
ax.savefig('vgg_stat_plot.png', dpi=200, bbox_inches="tight")

# %%
ax.savefig('vgg_stat_plot.png', figsize=(1, 1), bbox_inches="tight")
# Out:
# /Users/mzvyagin/.pyenv/versions/3.8.5/lib/python3.8/site-packages/seaborn/axisgrid.py:56: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "figsize" which is no longer supported as of 3.3 and will become an error two minor releases later
#   self.fig.savefig(*args, **kwargs)

# %% [markdown]
# ### Generation of DenseNet Plots

# %%
densenet_df = pd.read_csv('../wandb_results/densenet_cifar10_wandb_export.csv')

# %%
dense_all_stats = list(densenet_df['pt_test_acc'])
dense_all_stats.extend(list(densenet_df['tf_test_acc']))
dense_all_stats.extend(list(densenet_df['accuracy_diff']))

dense_all_names = (['PT Test Accuracy']*400)
dense_all_names.extend(['TF Test Accuracy']*400)
dense_all_names.extend(['Accuracy Diff']*400)

# %%
dense_stats_df = pd.DataFrame({'Value': dense_all_stats, 'Metric': dense_all_names})

# %%
# plt.rcParams['legend.loc'] = 'upper right'
ax = sns.displot(dense_stats_df, x="Value", hue="Metric", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, aspect=1)
plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
plt.setp(ax._legend.get_title(), fontsize='16')
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
ax._legend._loc_real = 9
plt.tight_layout()
ax.savefig('dense_stat_plot.png', dpi=200)

# %% [markdown]
# ### Generation of ResNet Plots

# %%
resnet_df = pd.read_csv('../wandb_results/resnet_cifar10_wandb_export.csv')

# %%
resnet_all_stats = list(resnet_df['pt_test_acc'])
resnet_all_stats.extend(list(resnet_df['tf_test_acc']))
resnet_all_stats.extend(list(resnet_df['accuracy_diff']))

resnet_all_names = (['PT Test Accuracy']*400)
resnet_all_names.extend(['TF Test Accuracy']*400)
resnet_all_names.extend(['Accuracy Diff']*400)

# %%
resnet_stats_df = pd.DataFrame({'Value': resnet_all_stats, 'Metric': resnet_all_names})

# %%
ax = sns.displot(resnet_stats_df, x="Value", hue="Metric", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, aspect=1.5, legend=False)
# plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
# plt.setp(ax._legend.get_title(), fontsize='16')
# ax._legend._loc_real = 1
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
plt.tight_layout()
ax.savefig('resnet_stat_plot.png', dpi=200)
