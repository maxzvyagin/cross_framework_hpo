# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Generation of Plots for VGG

# %%
vgg_df = pd.read_csv('../wandb_results/vgg_cifar10_wandb_export.csv')

# %%
pt_test_acc
# Out:
#                     Name     State Notes      User  Tags  \
# 0    dual_train_7b5123e8  finished     -  mzvyagin   NaN
# 1    dual_train_c9e4a752  finished     -  mzvyagin   NaN
# 2    dual_train_644f6814  finished     -  mzvyagin   NaN
# 3    dual_train_6bcc7c46  finished     -  mzvyagin   NaN
# 4    dual_train_f4928a08  finished     -  mzvyagin   NaN
# ..                   ...       ...   ...       ...   ...
# 395  dual_train_1aa7a062  finished     -  mzvyagin   NaN
# 396  dual_train_1aa52bf2  finished     -  mzvyagin   NaN
# 397  dual_train_1aa41eb0  finished     -  mzvyagin   NaN
# 398  dual_train_1a8c47b8  finished     -  mzvyagin   NaN
# 399  dual_train_1a6fbf8a  finished     -  mzvyagin   NaN
#
#                       Created  Runtime  Sweep  adam_epsilon  batch_size  ...  \
# 0    2021-08-11T09:57:05.000Z     2225    NaN      0.013183          31  ...
# 1    2021-08-11T09:44:58.000Z      787    NaN      0.492191         405  ...
# 2    2021-08-11T09:42:08.000Z      898    NaN      0.029184         541  ...
# 3    2021-08-11T09:28:01.000Z      847    NaN      0.021607         625  ...
# 4    2021-08-11T09:24:41.000Z     1217    NaN      0.493852          72  ...
# ..                        ...      ...    ...           ...         ...  ...
# 395  2021-08-10T23:10:09.000Z      839    NaN      0.911216         532  ...
# 396  2021-08-10T23:10:09.000Z      484    NaN      0.536216         904  ...
# 397  2021-08-10T23:10:09.000Z      848    NaN      0.536216         532  ...
# 398  2021-08-10T23:10:09.000Z      813    NaN      0.536216         904  ...
# 399  2021-08-10T23:10:09.000Z      502    NaN      0.536216         532  ...
#
#                                pt_latest_training_loss  pt_test_acc  \
# 0    [2.3131141662597656,2.313114881515503,2.313115...     0.100087
# 1    [2.302753448486328,2.3025734424591064,2.302420...     0.363751
# 2    [2.2625341415405273,2.304319143295288,2.304006...     0.100808
# 3    [2.3024299144744873,2.303330183029175,2.303338...     0.100000
# 4    [2.232651472091675,1.771140217781067,1.6342797...     0.782711
# ..                                                 ...          ...
# 395  [2.3013951778411865,2.287933111190796,2.163907...     0.718387
# 396  [2.302377700805664,2.3022518157958984,2.301535...     0.634100
# 397  [2.3023550510406494,2.2956416606903076,2.10157...     0.734935
# 398  [2.3025152683258057,2.3021507263183594,2.30139...     0.708281
# 399  [2.302530288696289,2.301220178604126,2.2676339...     0.686865
#
#      tf_test_acc                                   tf_training_loss  \
# 0         0.1000  [2.38021183013916,2.3246960639953613,2.3195180...
# 1         0.4173  [4.576943397521973,4.470826148986816,4.2838997...
# 2         0.1000  [2.8559813499450684,2.3200604915618896,2.32036...
# 3         0.1000  [3.01017427444458,2.3183462619781494,2.3195827...
# 4         0.7921  [2.7020950317382812,2.2760565280914307,1.90335...
# ..           ...                                                ...
# 395       0.7020  [4.486162185668945,3.5292861461639404,2.308697...
# 396       0.5567  [4.514370918273926,3.986527919769287,2.4167852...
# 397       0.7428  [4.3817901611328125,2.6538569927215576,2.30813...
# 398       0.6935  [4.5184645652771,4.026893138885498,2.435429334...
# 399       0.7026  [4.381078243255615,2.6259655952453613,2.309865...
#
#      time_since_restore  time_this_iter_s  time_total_s  timestamp  \
# 0                   NaN               NaN           NaN        NaN
# 1                   NaN               NaN           NaN        NaN
# 2                   NaN               NaN           NaN        NaN
# 3                   NaN               NaN           NaN        NaN
# 4                   NaN               NaN           NaN        NaN
# ..                  ...               ...           ...        ...
# 395                 NaN               NaN           NaN        NaN
# 396                 NaN               NaN           NaN        NaN
# 397                 NaN               NaN           NaN        NaN
# 398                 NaN               NaN           NaN        NaN
# 399                 NaN               NaN           NaN        NaN
#
#     timesteps_since_restore training_iteration
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# ..                      ...                ...
# 395                     NaN                NaN
# 396                     NaN                NaN
# 397                     NaN                NaN
# 398                     NaN                NaN
# 399                     NaN                NaN
#
# [400 rows x 37 columns]

# %%
len(['pt_test_acc']*400)
# Out:
# 400

# %%
list(vgg_df['accuracy_diff'])

# %%
all_stats = list(vgg_df['pt_test_acc'])
all_stats.extend(list(vgg_df['tf_test_acc']))
all_stats.extend(list(vgg_df['accuracy_diff']))

all_names = (['PT Test Accuracy']*400)
all_names.extend(['TF Test Accuracy']*400)
all_names.extend(['Accuracy Diff']*400)

# %%
vgg_stats_df = pd.DataFrame({'Value': all_stats, 'Statistic': all_names})

# %%
plt.rcdefaults()

# %%
import matplotlib.pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 18
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE, figsize=(1, 1))  # fontsize of the figure title

# %%
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %%
viridis = sns.color_palette("viridis")
viridis_colors = [viridis[0], viridis[2], viridis[5]]

# %%
# sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
ax = sns.displot(vgg_stats_df, x="Value", hue="Statistic", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, legend=False, aspect=1.5)
# plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
# plt.setp(ax._legend.get_title(), fontsize='16')
# ax._legend._loc_real = 1
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
plt.tight_layout()
ax.savefig('vgg_stat_plot.png', dpi=200)

# %%
ax.savefig('vgg_stat_plot.png', figsize=(1, 1), bbox_inches="tight")
# Out:
# /Users/mzvyagin/.pyenv/versions/3.8.5/lib/python3.8/site-packages/seaborn/axisgrid.py:56: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "figsize" which is no longer supported as of 3.3 and will become an error two minor releases later
#   self.fig.savefig(*args, **kwargs)

# %% [markdown]
# ### Generation of DenseNet Plots

# %%
densenet_df = pd.read_csv('../wandb_results/densenet_cifar10_wandb_export.csv')

# %%
dense_all_stats = list(densenet_df['pt_test_acc'])
dense_all_stats.extend(list(densenet_df['tf_test_acc']))
dense_all_stats.extend(list(densenet_df['accuracy_diff']))

dense_all_names = (['PT Test Accuracy']*400)
dense_all_names.extend(['TF Test Accuracy']*400)
dense_all_names.extend(['Accuracy Diff']*400)

# %%
dense_stats_df = pd.DataFrame({'Value': dense_all_stats, 'Metric': dense_all_names})

# %%
# plt.rcParams['legend.loc'] = 'upper right'
ax = sns.displot(dense_stats_df, x="Value", hue="Metric", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, aspect=1)
plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
plt.setp(ax._legend.get_title(), fontsize='16')
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
ax._legend._loc_real = 9
plt.tight_layout()
ax.savefig('dense_stat_plot.png', dpi=200)

# %% [markdown]
# ### Generation of ResNet Plots

# %%
resnet_df = pd.read_csv('../wandb_results/resnet_cifar10_wandb_export.csv')

# %%
resnet_all_stats = list(resnet_df['pt_test_acc'])
resnet_all_stats.extend(list(resnet_df['tf_test_acc']))
resnet_all_stats.extend(list(resnet_df['accuracy_diff']))

resnet_all_names = (['PT Test Accuracy']*400)
resnet_all_names.extend(['TF Test Accuracy']*400)
resnet_all_names.extend(['Accuracy Diff']*400)

# %%
resnet_stats_df = pd.DataFrame({'Value': resnet_all_stats, 'Metric': resnet_all_names})

# %%
ax = sns.displot(resnet_stats_df, x="Value", hue="Metric", kind="kde", cut=0, bw_adjust=1, palette=viridis_colors, linewidth=2.5, aspect=1.5, legend=False)
# plt.setp(ax._legend.get_texts(), fontsize='14') # for legend text
# plt.setp(ax._legend.get_title(), fontsize='16')
# ax._legend._loc_real = 1
plt.xlim(0, 1.15)
plt.ylim(0, 2.6)
plt.axvline(0.994, c="crimson", lw=2.5)
plt.tight_layout()
ax.savefig('resnet_stat_plot.png', dpi=200)
